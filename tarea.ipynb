# %% [markdown]
# <a href="https://colab.research.google.com/github/dn229331-cloud/AI-2/blob/main/tarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tarea
#
# hacer un ejercicio de rendimiento con una curva de roc cada linea que usemos debe estar comentareada
# en gogle hacer el ejemplo del hola mundo del enseñar a la maquina a reconocer un digito y entenderlo y comentariarlo
#
# sacar la tabla de la curva rock y f1 score (la calidad que tenemos de ese modelo) despues guardamos y lo pasamos a github (entenderlo mirarlo y entenderlo )

# %% [markdown]
# en google colab hacer el ejercicio de mnsti vamos hacer un 0 para negro 255 para blanco se convierte en unas columnas despues evaluar los resultados con curva rock y f1 score: agregar comentarios propios para entender
#
# aplicar el algoritmo skyler
