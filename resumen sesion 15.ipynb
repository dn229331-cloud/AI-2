# %% [markdown]
# <a href="https://colab.research.google.com/github/dn229331-cloud/AI-2/blob/main/resumen%20sesion%2015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # sesion 15

# %% [markdown]
# modelos no supervisados:
#
# redes neuronales (mañana)
#
# Orden del caos:
# aprendizaje no supervisado seria el pastel entero el supervisado
# 1 datos no supervisados
# agrupamientos
# segmentacion
# dbscan
# anomalias
# 1  el reto es enconttrar la matematica oculta
# el agrupamiento es el verdadero motor en la toma de desiciones es lo que permite encontrar imegenes identicas
# 2 kmens: identifica cincogrupos distintos eficientemente: la ia usa metricas criticas, evalua que tan separado esta in grupo
# 3 para una computadora una imagen son millones de pixeles con kmens se puede agrupar en unos cuantos colores y acelera el costoso : entrenas etiquetar iterar es la combinacion perfecta
# 4 dbscan: algoritmis basado en densidad para identificar grupos continus de formas complejas,
# 5 anomalias y novedades: busa aislar eventos destrctivos y la detencion de novedades evita fasas alarmaas
# 6 mezclas gausianas: crea zonas de densidad que se adapta en puntos el modelo atravez de matematicas dice aja estos puntos aislados son anomalias
# criterios teoricos de informacion: BIC y AICmetricas para calcuular numeros exactos:
# ¿como desbloreatan valor con estos datos?
